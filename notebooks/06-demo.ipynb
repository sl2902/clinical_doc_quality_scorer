# %%
# !pip install pyngrok
# !pip install -q streamlit
# !pip install -q bitsandbytes
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.5.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-7.5.0-py3-none-any.whl (24 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.5.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 98.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 126.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 15.0 MB/s eta 0:00:00

# %%
# !git clone https://github.com/sl2902/clinical_doc_quality_scorer.git
# Out:
# Cloning into 'clinical_doc_quality_scorer'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (83/83), done.
# remote: Total 107 (delta 37), reused 86 (delta 23), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 46.59 KiB | 808.00 KiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %%
import sys
sys.path.append('./clinical_doc_quality_scorer/src')

# %%
get_ipython().system_raw('streamlit run clinical_doc_quality_scorer/src/app.py &')

# %%
from pyngrok import ngrok
from google.colab import userdata
ngrok_token = userdata.get("NGROK_AUTHTOKEN")
ngrok.set_auth_token(ngrok_token)

# %%
public_url = ngrok.connect(8501)

# %%
public_url
# Out:
# <NgrokTunnel: "https://unchevroned-voncile-commentarial.ngrok-free.dev" -> "http://localhost:8501">
