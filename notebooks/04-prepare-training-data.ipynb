# %%
# !git clone https://github.com/sl2902/clinical_doc_quality_scorer.git
# Out:
# Cloning into 'clinical_doc_quality_scorer'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 95 (delta 34), reused 76 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (95/95), 34.89 KiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
import sys
sys.path.append('/kaggle/working/clinical_doc_quality_scorer/')

# %%
from src import config
from src.prepare_training_data import (
    create_training_datasets
)

# %% [markdown]
# #### - Note: Kaggle is fickle at times. The dataset created on Kaggle sometimes appear under /kaggle/input/ or under /kaggle/input/datasets/username/; the path names could use either `_` or `-`. So list the files to get the correct path if you encounter a `File Not Found Error`
#
# Steps to run
# - Click on Save Version at the top right corner
# - Leave default version name, and ensure Version Type is Save & Run All (Commit). Click Continue
# - Check log for successful completion
# - Access the files from the Output tab. Download them, and then upload them to Kaggle as a dataset

# %%
if __name__ == "__main__":
    # cannot write to /kaggle/input, hence saving the data in working directory. Other option is to run
    # the script locally. But you will need to have the input datasets loaded locally. [brooks, chen, gold]
    data_dir = "/kaggle/input/datasets/laxmsun/persona-data-dir"
    output_dir = "/kaggle/working/data"
    create_training_datasets(data_dir=data_dir, output_data_dir=output_dir)
# Out:
# ================================================================================
# PREPARING TRAINING DATA
# ================================================================================
#
# 1. Loading notes...
# Loaded: gold_uri_000
# Loaded: gold_uri_001
# Loaded: gold_uri_002
# Loaded: gold_uri_003
# Loaded: gold_uri_004
# Loaded: gold_uri_005
# Loaded: gold_uri_006
# Loaded: gold_uri_007
# Loaded: gold_uri_008
# Loaded: gold_uri_009
# Loaded: gold_htn_followup_000
# Loaded: gold_htn_followup_001
# Loaded: gold_htn_followup_002
# Loaded: gold_htn_followup_003
# Loaded: gold_htn_followup_004
# Loaded: gold_htn_followup_005
# Loaded: gold_htn_followup_006
# Loaded: gold_htn_followup_007
# Loaded: gold_htn_followup_008
# Loaded: gold_htn_followup_009
# Loaded: gold_t2dm_000
# Loaded: gold_t2dm_001
# Loaded: gold_t2dm_002
# Loaded: gold_t2dm_003
# Loaded: gold_t2dm_004
# Loaded: gold_t2dm_005
# Loaded: gold_t2dm_006
# Loaded: gold_t2dm_007
# Loaded: gold_t2dm_008
# Loaded: gold_t2dm_009
# Loaded: gold_back_pain_000
# Loaded: gold_back_pain_001
# Loaded: gold_back_pain_002
# Loaded: gold_back_pain_003
# Loaded: gold_back_pain_004
# Loaded: gold_back_pain_005
# Loaded: gold_back_pain_006
# Loaded: gold_back_pain_007
# Loaded: gold_back_pain_008
# Loaded: gold_back_pain_009
# Loaded: gold_annual_physical_000
# Loaded: gold_annual_physical_001
# Loaded: gold_annual_physical_002
# Loaded: gold_annual_physical_003
# Loaded: gold_annual_physical_004
# Loaded: gold_annual_physical_005
# Loaded: gold_annual_physical_006
# Loaded: gold_annual_physical_007
# Loaded: gold_annual_physical_008
# Loaded: gold_annual_physical_009
# Loaded: brooks_uri_000
# Loaded: brooks_uri_001
# Loaded: brooks_uri_002
# Loaded: brooks_uri_003
# Loaded: brooks_uri_004
# Loaded: brooks_uri_005
# Loaded: brooks_uri_006
# Loaded: brooks_uri_007
# Loaded: brooks_uri_008
# Loaded: brooks_uri_009
# Loaded: brooks_htn_followup_000
# Loaded: brooks_htn_followup_001
# Loaded: brooks_htn_followup_002
# Loaded: brooks_htn_followup_003
# Loaded: brooks_htn_followup_004
# Loaded: brooks_htn_followup_005
# Loaded: brooks_htn_followup_006
# Loaded: brooks_htn_followup_007
# Loaded: brooks_htn_followup_008
# Loaded: brooks_htn_followup_009
# Loaded: brooks_t2dm_000
# Loaded: brooks_t2dm_001
# Loaded: brooks_t2dm_002
# Loaded: brooks_t2dm_003
# Loaded: brooks_t2dm_004
# Loaded: brooks_t2dm_005
# Loaded: brooks_t2dm_006
# Loaded: brooks_t2dm_007
# Loaded: brooks_t2dm_008
# Loaded: brooks_t2dm_009
# Loaded: brooks_back_pain_000
# Loaded: brooks_back_pain_001
# Loaded: brooks_back_pain_002
# Loaded: brooks_back_pain_003
# Loaded: brooks_back_pain_004
# Loaded: brooks_back_pain_005
# Loaded: brooks_back_pain_006
# Loaded: brooks_back_pain_007
# Loaded: brooks_back_pain_008
# Loaded: brooks_back_pain_009
# Loaded: brooks_annual_physical_000
# Loaded: brooks_annual_physical_001
# Loaded: brooks_annual_physical_002
# Loaded: brooks_annual_physical_003
# Loaded: brooks_annual_physical_004
# Loaded: brooks_annual_physical_005
# Loaded: brooks_annual_physical_006
# Loaded: brooks_annual_physical_007
# Loaded: brooks_annual_physical_008
# Loaded: brooks_annual_physical_009
# Loaded: chen_uri_000
# Loaded: chen_uri_001
# Loaded: chen_uri_002
# Loaded: chen_uri_003
# Loaded: chen_uri_004
# Loaded: chen_uri_005
# Loaded: chen_uri_006
# Loaded: chen_uri_007
# Loaded: chen_uri_008
# Loaded: chen_uri_009
# Loaded: chen_htn_followup_000
# Loaded: chen_htn_followup_001
# Loaded: chen_htn_followup_002
# Loaded: chen_htn_followup_003
# Loaded: chen_htn_followup_004
# Loaded: chen_htn_followup_005
# Loaded: chen_htn_followup_006
# Loaded: chen_htn_followup_007
# Loaded: chen_htn_followup_008
# Loaded: chen_htn_followup_009
# Loaded: chen_t2dm_000
# Loaded: chen_t2dm_001
# Loaded: chen_t2dm_002
# Loaded: chen_t2dm_003
# Loaded: chen_t2dm_004
# Loaded: chen_t2dm_005
# Loaded: chen_t2dm_006
# Loaded: chen_t2dm_007
# Loaded: chen_t2dm_008
# Loaded: chen_t2dm_009
# Loaded: chen_back_pain_000
# Loaded: chen_back_pain_001
# Loaded: chen_back_pain_002
# Loaded: chen_back_pain_003
# Loaded: chen_back_pain_004
# Loaded: chen_back_pain_005
# Loaded: chen_back_pain_006
# Loaded: chen_back_pain_007
# Loaded: chen_back_pain_008
# Loaded: chen_back_pain_009
# Loaded: chen_annual_physical_000
# Loaded: chen_annual_physical_001
# Loaded: chen_annual_physical_002
# Loaded: chen_annual_physical_003
# Loaded: chen_annual_physical_004
# Loaded: chen_annual_physical_005
# Loaded: chen_annual_physical_006
# Loaded: chen_annual_physical_007
# Loaded: chen_annual_physical_008
# Loaded: chen_annual_physical_009
#
# Total notes loaded: 150
#
# 2. Splitting dataset...
# Train: 120, Test: 30
# Saved train/test splits
#
# 3. Formatting for fine-tuning...
#   completeness: 120 train, 30 test
#   accuracy: 120 train, 30 test
#   compliance: 120 train, 30 test
#   risk: 120 train, 30 test
#   clarity: 120 train, 30 test
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Outputs:
#   - /kaggle/working/data/splits/train_split.json (120 notes)
#   - /kaggle/working/data/splits/test_split.json (30 notes)
#   - /kaggle/working/data/finetuning/[dimension]_train.json (5 files)
#   - /kaggle/working/data/finetuning/[dimension]_test.json (5 files)
