# %%
# %%capture
# !uv pip install transformers accelerate bitsandbytes

# %%
# !git clone https://github.com/sl2902/clinical_doc_quality_scorer.git
# Out:
# Cloning into 'clinical_doc_quality_scorer'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 39 (delta 8), reused 31 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 16.56 KiB | 5.52 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
import sys
sys.path.append('/kaggle/working/clinical_doc_quality_scorer/')

# %%
from src import config
from src.data_generation import (
    clear_gpu_memory,
    get_credentials,
    load_medgemma,
    run_personas,
)

# %% [markdown]
# #### - Note: Kaggle is fickle at times. The dataset created on Kaggle sometimes appear under /kaggle/input/ or under /kaggle/input/datasets/username/; the path names could use either `_` or `-`. So list the files to get the correct path if you encounter a `File Not Found Error`
#
# Steps to run
# - Add variable `hf_token`. Click on Add-ons -> Secrets
# - Click on Save Version at the top right corner
# - Leave default version name, and ensure Version Type is Save & Run All (Commit). Click Continue
# - Check log for successful completion
# - Access the files from the Output tab. Download them, and then upload them to Kaggle as a dataset

# %%
if __name__ == "__main__":
    clear_gpu_memory()
    # Load model once
    tokenizer, model = load_medgemma(token=get_credentials())

    run_personas(
        tokenizer, 
        model, 
        base_path="/kaggle/input/datasets/laxmsun/gold-prompts/generated_prompts", 
        scenarios=['uri'], 
        n_notes=1,
        personas=["brooks"],
        persona_path="/kaggle/input/datasets/laxmsun/personas/personas",
    )
# Out:
# Loading google/medgemma-4b-it...
# tokenizer_config.json:   0%|          | 0.00/1.16M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.69M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# chat_template.jinja:   0%|          | 0.00/1.53k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.47k [00:00<?, ?B/s]
# 2026-02-11 15:01:08.297603: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770822068.469780      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770822068.517169      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770822068.907196      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770822068.907229      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770822068.907232      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770822068.907235      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# model.safetensors.index.json:   0%|          | 0.00/90.6k [00:00<?, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.64G [00:00<?, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.96G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/156 [00:00<?, ?B/s]
# uri: Transformed 1/n_notes
